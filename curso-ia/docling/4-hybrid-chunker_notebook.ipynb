# %%
from docling.document_converter import DocumentConverter
from docling.chunking import HybridChunker
from docling_core.transforms.chunker.tokenizer.huggingface import HuggingFaceTokenizer
from transformers import AutoTokenizer

EMBED_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
MAX_TOKENS = 300

converter = DocumentConverter()
result = converter.convert("./2408.09869v5.pdf")

document = result.document
# Out:
# 2025-11-16 17:59:13,769 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-16 17:59:13,904 - INFO - Going to convert document batch...
# 2025-11-16 17:59:13,906 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 44ae89a68fc272bc7889292e9b5a1bad
# 2025-11-16 17:59:13,941 - INFO - Loading plugin 'docling_defaults'
# 2025-11-16 17:59:13,945 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-11-16 17:59:13,964 - INFO - Loading plugin 'docling_defaults'
# 2025-11-16 17:59:13,972 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-11-16 17:59:14,899 - INFO - Auto OCR model selected ocrmac.
# 2025-11-16 17:59:14,909 - INFO - Accelerator device: 'mps'
# 2025-11-16 17:59:16,863 - INFO - Accelerator device: 'mps'
# 2025-11-16 17:59:17,535 - INFO - Processing document 2408.09869v5.pdf
# 2025-11-16 17:59:41,437 - INFO - Finished converting document 2408.09869v5.pdf in 27.67 sec.

# %%
tokenizer = HuggingFaceTokenizer(
    tokenizer=AutoTokenizer.from_pretrained(EMBED_MODEL),
    max_tokens=MAX_TOKENS
)

chunker = HybridChunker(
    tokenizer=tokenizer,
    max_tokens=MAX_TOKENS,
    merge_peers=True
)

chunks = list(chunker.chunk(document))
len(chunks)
# Out:
# 42

# %%
for i, chunk in enumerate(chunks):
    print(f"=== Chunk {i} ===\n")
    txt_tokens = tokenizer.count_tokens(chunk.text)
    print(f"chunk.text ({txt_tokens} tokens:)\n{chunk.text!r}")
